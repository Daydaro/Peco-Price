# %%
from notify_run import Notify

# %%
notify = Notify()

# %%
notify.register()
# Out:
# Endpoint: https://notify.run/VfbuSQHOpejQ5kRiYFZx
# To subscribe, open: https://notify.run/c/VfbuSQHOpejQ5kRiYFZx
# Or scan this QR code:

# %%
notify.send()
